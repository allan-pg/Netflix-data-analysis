# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
data = pd.read_csv(r'C:\Users\Admin\Desktop\csv files\netflix1.csv')

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8794   s8785    Movie              Yoko and His Friends        Not Given
# 8795   s8796  TV Show                   Yu-Gi-Oh! Arc-V        Not Given
# 8796   s8797  TV Show                        Yunus Emre        Not Given
# 8797   s8798  TV Show                         Zak Storm        Not Given
# 8798   s8801  TV Show                Zindagi Gulzar Hai        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
#getting some basic information about the data set
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#to show the number of rows and columns
data.shape
# Out:
# (8799, 10)

# %%
#total no. of values in the dataset
data.size
# Out:
# 87990

# %%
#to show the columns
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
#to show the data types in each colmns
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
#show a detailed information of the data set at once
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8799 entries, 0 to 8798
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8799 non-null   object
#  1   type          8799 non-null   object
#  2   title         8799 non-null   object
#  3   director      8799 non-null   object
#  4   country       8799 non-null   object
#  5   date_added    8799 non-null   object
#  6   release_year  8799 non-null   int64
#  7   rating        8799 non-null   object
#  8   duration      8799 non-null   object
#  9   listed_in     8799 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 687.5+ KB

# %%
#are there any duplicates in the record if yes remove the duplicate
#find the duplicated columns
data[data.duplicated()]
# Out:
#      show_id     type                 title         director        country  \
# 8790      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 8791   s8784  TV Show                  Yoko        Not Given       Pakistan
# 8792   s8786  TV Show                   YOM        Not Given       Pakistan
# 8793   s8781  TV Show          Yo-Kai Watch        Not Given  United States
# 8794   s8785    Movie  Yoko and His Friends        Not Given         Russia
# 8795   s8796  TV Show       Yu-Gi-Oh! Arc-V        Not Given          Japan
# 8796   s8797  TV Show            Yunus Emre        Not Given         Turkey
# 8797   s8798  TV Show             Zak Storm        Not Given  United States
# 8798   s8801  TV Show    Zindagi Gulzar Hai        Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8790   9/25/2021          2020  PG-13     90 min
# 8791   6/23/2018          2016   TV-Y   1 Season
# 8792  06/07/2018          2016  TV-Y7   1 Season
# ...

# %%
#delete the duplicated columns
data.drop_duplicates(inplace=True)

# %%
#our data now has 8790 columns from 8799
data.shape
# Out:
# (8790, 10)

# %%
#to check for null values
data.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False  False  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8785    False  False  False     False    False       False         False
# 8786    False  False  False     False    False       False         False
# 8787    False  False  False     False    False       False         False
# 8788    False  False  False     False    False       False         False
# 8789    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# ...

# %%
#to show th sum of all null values in a column
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
#Is there any null values in the data set? show with a heatmap
sns.heatmap(data.isnull())
plt.show() #from the heatmap analysis there are no null values

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
#for 'House of Cards' what is the show id and who is the director?
#to find the show 
data.title == 'House of Cards'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8785    False
# 8786    False
# 8787    False
# 8788    False
# 8789    False
# Name: title, Length: 8790, dtype: bool

# %%
#To find the show in a data frame
data[data.title == 'House of Cards']
# Out:
#      show_id     type           title   director        country date_added  \
# 6802   s1060  TV Show  House of Cards  Not Given  United States  4/14/2021
#
#       release_year rating   duration                listed_in
# 6802          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers

# %%
#print the show id
data[data.title == 'House of Cards'].show_id
# Out:
# 6802    s1060
# Name: show_id, dtype: object

# %%
#to find the director
data[data.title == 'House of Cards'].director
# Out:
# 6802    Not Given
# Name: director, dtype: object

# %%
#Also to show a particular record usind isin()
data[data['title'].isin(['House of Cards'])]
# Out:
#      show_id     type           title   director        country date_added  \
# 6802   s1060  TV Show  House of Cards  Not Given  United States  4/14/2021
#
#       release_year rating   duration                listed_in
# 6802          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers

# %%
#to show the record using str.contains()
data[data['title'].str.contains('House of Cards')]
# Out:
#      show_id     type           title   director        country date_added  \
# 6802   s1060  TV Show  House of Cards  Not Given  United States  4/14/2021
#
#       release_year rating   duration                listed_in
# 6802          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers

# %%
#In whic year was the highest number of the tv shows and movies released? show with a line graph
#check the dtypes to know which datatype is year
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# dtype: object

# %%
#incase the release year was an object
pd.to_datetime(data['release_year'])
# Out:
# 0      1970-01-01 00:00:00.000002020
# 1      1970-01-01 00:00:00.000002021
# 2      1970-01-01 00:00:00.000002021
# 3      1970-01-01 00:00:00.000002021
# 4      1970-01-01 00:00:00.000001993
#                     ...
# 8785   1970-01-01 00:00:00.000002016
# 8786   1970-01-01 00:00:00.000002016
# 8787   1970-01-01 00:00:00.000002012
# 8788   1970-01-01 00:00:00.000002016
# 8789   1970-01-01 00:00:00.000002016
# Name: release_year, Length: 8790, dtype: datetime64[ns]

# %%
data.release_year.value_counts()
# Out:
# 2018    1146
# 2017    1030
# 2019    1030
# 2020     953
# 2016     901
#         ...
# 1966       1
# 1959       1
# 1925       1
# 1947       1
# 1961       1
# Name: release_year, Length: 74, dtype: int64

# %%
data['release_year'].value_counts().plot(kind = 'line')
# Out:
# <AxesSubplot:>

# %%
#to group all unique column elements
data.groupby('type').type.count()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
#show all movies released in 2000
data[(data['type'] == 'Movie') & (data['release_year'] == 2000)]
# Out:
#      show_id   type                                              title  \
# 252     s181  Movie                 The Nutty Professor II: The Klumps
# 494     s351  Movie                                      Space Cowboys
# 503     s360  Movie                       The Original Kings of Comedy
# 717     s567  Movie                                   Charlie's Angels
# 741     s594  Movie                                           Snow Day
# 859     s780  Movie                                  Battlefield Earth
# 983     s953  Movie                               The Whole Nine Yards
# 2644   s3473  Movie                        Rugrats in Paris: The Movie
# 3299   s4546  Movie             Monty Python: Before the Flying Circus
# 3420   s4724  Movie                                               Fiza
# 3585   s4957  Movie                        Phir Bhi Dil Hai Hindustani
# 4249   s5954  Movie                             Joseph: King of Dreams
# ...

# %%
#show title of only TV shows released in the united states only
#filter
data[(data['type'] == 'TV Show') & (data['country'] == 'United States')]['title']
# Out:
# 2                                         Midnight Mass
# 20                                True: Magical Friends
# 21                               True: Wonderful Wishes
# 22                               Dance & Sing with True
# 27      Monsters Inside: The 24 Faces of Billy Milligan
#                              ...
# 8773                               When Calls the Heart
# 8777                                          Winsanity
# 8779                                  Women Behind Bars
# 8782                                       Yo-Kai Watch
# 8786                                          Zak Storm
# Name: title, Length: 845, dtype: object
